# %% [markdown]
# #### Business Scenario
# Manager would like to have a tool for accurate forecast of next-month revenue, to support AAVAIL while transitioning wolrdwide to an à-la-carte approach for customer pricing.
#
#
# The ideal data for this would be historical revenue data for those countries who already adpoted the new pricing model, combined with independent variables which could be positively correlated to the revenue, such as service utilization, seasonality, amount of new platform content released and strength of marketing campaign.

# %%
import json
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = []
for file in os.listdir("../cs-train/"):
    with open(os.path.join("../cs-train", file)) as f:
        data.append(pd.DataFrame.from_dict(json.load(f)))

# %%
for df in data:
    df.columns = ["Country", "Customer ID", "Invoice", "Price", "Stream ID", "Times Viewed", "Year", "Month", "Day"]

# %%
df = pd.concat(data)
df
# Out:
#               Country  Customer ID Invoice  Price Stream ID  Times Viewed  \
# 0      United Kingdom      13085.0  489434   6.95     85048            12
# 1      United Kingdom          NaN  489597   8.65     22130             1
# 2      United Kingdom          NaN  489597   1.70     22132             6
# 3      United Kingdom          NaN  489597   1.70     22133             4
# 4      United Kingdom          NaN  489597   0.87     22134             1
# ...               ...          ...     ...    ...       ...           ...
# 42013  United Kingdom      15628.0  562163   0.85     21544            12
# 42014  United Kingdom      15628.0  562163   1.95    47591D             8
# 42015  United Kingdom      15628.0  562163   0.83     23167            12
# 42016  United Kingdom      15628.0  562163   4.95     22138             3
# 42017  United Kingdom      15628.0  562163   1.65     22558            12
#
#        Year Month Day
# 0      2017    11  28
# 1      2017    11  28
# 2      2017    11  28
# 3      2017    11  28
# 4      2017    11  28
# ...     ...   ...  ..
# 42013  2019    07  31
# 42014  2019    07  31
# 42015  2019    07  31
# 42016  2019    07  31
# 42017  2019    07  31
#
# [815011 rows x 9 columns]

# %%
len(df["Country"].unique())
# Out:
# 43

# %%
df["date"] = pd.to_datetime(df[["Year", "Month", "Day"]])

# %%
df
# Out:
#               Country  Customer ID Invoice  Price Stream ID  Times Viewed  \
# 0      United Kingdom      13085.0  489434   6.95     85048            12
# 1      United Kingdom          NaN  489597   8.65     22130             1
# 2      United Kingdom          NaN  489597   1.70     22132             6
# 3      United Kingdom          NaN  489597   1.70     22133             4
# 4      United Kingdom          NaN  489597   0.87     22134             1
# ...               ...          ...     ...    ...       ...           ...
# 42013  United Kingdom      15628.0  562163   0.85     21544            12
# 42014  United Kingdom      15628.0  562163   1.95    47591D             8
# 42015  United Kingdom      15628.0  562163   0.83     23167            12
# 42016  United Kingdom      15628.0  562163   4.95     22138             3
# 42017  United Kingdom      15628.0  562163   1.65     22558            12
#
#        Year Month Day       date
# 0      2017    11  28 2017-11-28
# 1      2017    11  28 2017-11-28
# 2      2017    11  28 2017-11-28
# 3      2017    11  28 2017-11-28
# 4      2017    11  28 2017-11-28
# ...     ...   ...  ..        ...
# 42013  2019    07  31 2019-07-31
# 42014  2019    07  31 2019-07-31
# 42015  2019    07  31 2019-07-31
# 42016  2019    07  31 2019-07-31
# 42017  2019    07  31 2019-07-31
#
# [815011 rows x 10 columns]

# %%
df["Invoice"].value_counts()
# Out:
# 537434    1350
# 538071    1304
# 537638    1202
# 537237    1194
# 536876    1186
#           ...
# 528953       1
# 504625       1
# 553163       1
# 512169       1
# 520332       1
# Name: Invoice, Length: 42646, dtype: int64

# %%
df.groupby(by="Country").agg({"Price": "sum"}).sort_values(by="Price", ascending=False)
# Out:
#                              Price
# Country
# United Kingdom        3.521514e+06
# EIRE                  1.070692e+05
# Germany               4.927182e+04
# France                4.056514e+04
# Norway                3.849475e+04
# Spain                 1.604099e+04
# Hong Kong             1.445257e+04
# Portugal              1.352867e+04
# Singapore             1.317592e+04
# Netherlands           1.232280e+04
# Belgium               1.119061e+04
# Switzerland           9.284050e+03
# Sweden                7.876760e+03
# Channel Islands       7.610120e+03
# Australia             6.872630e+03
# Malta                 6.085340e+03
# Italy                 5.910190e+03
# Cyprus                4.976300e+03
# Austria               3.390890e+03
# Finland               3.364650e+03
# RSA                   3.105750e+03
# Unspecified           3.045360e+03
# Greece                2.437370e+03
# United Arab Emirates  2.400210e+03
# Denmark               1.818510e+03
# Poland                1.510710e+03
# USA                   1.185100e+03
# Japan                 1.083120e+03
# Canada                1.053100e+03
# Iceland               5.098600e+02
# Lithuania             4.944100e+02
# Israel                4.575900e+02
# Bahrain               4.394900e+02
# Lebanon               3.586100e+02
# European Community    2.940500e+02
# Brazil                2.563100e+02
# Thailand              2.279700e+02
# Korea                 1.502400e+02
# West Indies           1.227700e+02
# Nigeria               1.092800e+02
# Bermuda               8.470000e+01
# Czech Republic        3.183000e+01
# Saudi Arabia          2.411000e+01

# %% [markdown]
# The available data contains monthly data on customer pricing, i.e. how much customers have been charged each month. This variable is directly correlated with the expected revenue, and it is thus here chosen as the target variable to be forecasted by our models.
#
#
# The data spans a bit less than 2 years for 42 countries + Unspecified ones.
# Given the prototypical nature of the solution we will restrict ourselves to predicting the next-month total pricing for the countries with the highest revenue.

# %%
df = df.sort_values(by="date").reset_index(drop=True)
df.to_csv("../combined.csv")
