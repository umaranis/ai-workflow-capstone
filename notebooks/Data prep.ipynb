# %%
import json
import pandas as pd
import os
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv("../combined.csv", index_col=0)
df
# Out:
#                Country  Customer ID Invoice  Price Stream ID  Times Viewed  \
# 0       United Kingdom      13085.0  489434   6.95     85048            12
# 1       United Kingdom      13085.0  489434   6.75    79323W            12
# 2       United Kingdom      13085.0  489434   2.10     22041            21
# 3       United Kingdom      13085.0  489434   1.25     21232             5
# 4       United Kingdom      13085.0  489434   1.65     22064            17
# ...                ...          ...     ...    ...       ...           ...
# 815006  United Kingdom      16098.0  562271   3.75     22725             2
# 815007  United Kingdom      16098.0  562271   3.75     22726            12
# 815008  United Kingdom      16098.0  562271   3.75     22727             6
# 815009  United Kingdom      14056.0  562269   2.95     22090             2
# 815010  United Kingdom      15628.0  562163   1.65     22558            12
#
#         Year  Month  Day        date
# 0       2017     11   28  2017-11-28
# 1       2017     11   28  2017-11-28
# 2       2017     11   28  2017-11-28
# 3       2017     11   28  2017-11-28
# 4       2017     11   28  2017-11-28
# ...      ...    ...  ...         ...
# 815006  2019      7   31  2019-07-31
# 815007  2019      7   31  2019-07-31
# 815008  2019      7   31  2019-07-31
# 815009  2019      7   31  2019-07-31
# 815010  2019      7   31  2019-07-31
#
# [815011 rows x 10 columns]

# %%
#aggregate per country and per day
agg_df = df.groupby(by=["Country", "date"]).agg({"Price": "sum", "Times Viewed": "sum"}).reset_index()
agg_df
# Out:
#           Country        date   Price  Times Viewed
# 0       Australia  2017-11-28   40.40            97
# 1       Australia  2017-12-04   10.10             4
# 2       Australia  2017-12-05    2.50             5
# 3       Australia  2017-12-15    6.65            40
# 4       Australia  2018-02-11   27.75           144
# ...           ...         ...     ...           ...
# 2529  Unspecified  2019-06-17   42.10            51
# 2530  Unspecified  2019-07-05  167.97           400
# 2531  Unspecified  2019-07-11   51.91           152
# 2532  Unspecified  2019-07-25  407.17           277
# 2533  West Indies  2018-08-20  122.77           313
#
# [2534 rows x 4 columns]

# %% [markdown]
# Let's look at the data

# %%
plot_df = agg_df.loc[agg_df["Country"]=="France", :]
plt.figure(figsize=[15, 6])
plt.plot(pd.to_datetime(plot_df["date"]), plot_df["Price"])
plt.plot(pd.to_datetime(plot_df["date"]), plot_df["Times Viewed"])

# %% [markdown]
# There are some signs of correlation..
#
# What about data distribution?

# %%
plot_df = agg_df.loc[agg_df["Country"]=="EIRE", :]
plt.figure(figsize=[10, 6])
plt.hist(plot_df["Price"], bins=40)
plt.show()

# %% [markdown]
# The histogram reveals a highly skewed distribution. This might result in sub-optimal performance for some class of models (e.g. linear models). One way to fix this would be to train on the revenue _change_ rather than the revenue itself.

# %%
agg_df["date"] = pd.to_datetime(agg_df["date"])
# add missing values
appended_dfs = []
for country in agg_df["Country"].unique():
    temp_df = agg_df.loc[agg_df["Country"]==country, :]
    dr = pd.date_range(temp_df["date"].min(), 
                       temp_df["date"].max())
    temp_df = temp_df.set_index("date")
    s = temp_df["Price"]
    s = s.reindex(dr, fill_value=0)
    #temp_df = temp_df.reset_index()
    temp_df = pd.DataFrame(s.reset_index())
    temp_df["Country"] = country
    appended_dfs.append(temp_df)

# %%
df = pd.concat(appended_dfs)
df.columns = ["date", "Price", "Country"]

# %%
df
# Out:
#           date   Price      Country
# 0   2017-11-28   40.40    Australia
# 1   2017-11-29    0.00    Australia
# 2   2017-11-30    0.00    Australia
# 3   2017-12-01    0.00    Australia
# 4   2017-12-02    0.00    Australia
# ..         ...     ...          ...
# 552 2019-07-22    0.00  Unspecified
# 553 2019-07-23    0.00  Unspecified
# 554 2019-07-24    0.00  Unspecified
# 555 2019-07-25  407.17  Unspecified
# 0   2018-08-20  122.77  West Indies
#
# [18094 rows x 3 columns]

# %%
for country in df["Country"].unique():
    df.loc[df["Country"]==country, "Price_7d"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=7).sum()
    df.loc[df["Country"]==country, "Price_14d"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=14).sum()
    df.loc[df["Country"]==country, "Price_21d"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=21).sum()
    df.loc[df["Country"]==country, "Price_28d"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=28).sum()
    df.loc[df["Country"]==country, "Price_7d_der"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=2).apply(np.diff).rolling(window=7).mean()
    df.loc[df["Country"]==country, "Price_14d_der"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=2).apply(np.diff).rolling(window=14).mean()
    df.loc[df["Country"]==country, "Price_21d_der"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=2).apply(np.diff).rolling(window=21).mean()
    df.loc[df["Country"]==country, "Price_28d_der"] = df.loc[df["Country"]==country, "Price"].shift(1).rolling(window=2).apply(np.diff).rolling(window=28).mean()
df.dropna()
# Out:
#           date   Price      Country  Price_7d     Price_14d  Price_21d  \
# 29  2017-12-27    0.00    Australia       0.0  6.650000e+00       6.65
# 30  2017-12-28    0.00    Australia       0.0  6.650000e+00       6.65
# 31  2017-12-29    0.00    Australia       0.0  6.650000e+00       6.65
# 32  2017-12-30    0.00    Australia       0.0 -1.776357e-15       6.65
# 33  2017-12-31    0.00    Australia       0.0 -1.776357e-15       6.65
# ..         ...     ...          ...       ...           ...        ...
# 551 2019-07-21    0.00  Unspecified       0.0  5.191000e+01     219.88
# 552 2019-07-22    0.00  Unspecified       0.0  5.191000e+01     219.88
# 553 2019-07-23    0.00  Unspecified       0.0  5.191000e+01     219.88
# 554 2019-07-24    0.00  Unspecified       0.0  5.191000e+01     219.88
# 555 2019-07-25  407.17  Unspecified       0.0  5.191000e+01     219.88
#
#      Price_28d  Price_7d_der  Price_14d_der  Price_21d_der  Price_28d_der
# 29       19.25           0.0          0.000      -0.119048      -1.442857
# 30       19.25           0.0          0.000       0.000000       0.000000
# 31       19.25           0.0          0.000       0.000000       0.000000
# 32       19.25           0.0         -0.475       0.000000       0.000000
# 33       19.25           0.0          0.000       0.000000       0.000000
# ..         ...           ...            ...            ...            ...
# 551     219.88           0.0          0.000       0.000000       0.000000
# 552     219.88           0.0          0.000       0.000000       0.000000
# 553     219.88           0.0          0.000       0.000000       0.000000
# 554     219.88           0.0          0.000       0.000000       0.000000
# 555     219.88           0.0          0.000       0.000000       0.000000
#
# [16938 rows x 11 columns]

# %%
df["Month"] = df["date"].dt.month
df["Day"] = df["date"].dt.day

# %%
#target var
for country in df["Country"].unique():
    df.loc[df["Country"]==country, "target"] = df.loc[df["Country"]==country, "Price"].shift(-30).rolling(30).sum()

# %%
df.loc[df["Country"]=="Australia"].dropna().head(60)
# Out:
#          date  Price    Country  Price_7d     Price_14d     Price_21d  \
# 29 2017-12-27   0.00  Australia      0.00  6.650000e+00  6.650000e+00
6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 38  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 39  6.650000e+00      0.000000       0.000000      -0.316667       0.000000
# 40  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 41  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 42  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 43  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 44  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 45  6.650000e+00      0.000000       0.000000       0.000000       0.000000
# 46 -1.776357e-15      0.000000       0.000000       0.000000      -0.237500
# 47 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 48 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 49 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 50 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 51 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 52 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 53 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 54 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 55 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 56 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 57 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 58 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 59 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 60 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 61 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 62 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 63 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 64 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 65 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 66 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 67 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 68 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 69 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 70 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 71 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 72 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 73 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 74 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 75 -1.776357e-15      0.000000       0.000000       0.000000       0.000000
# 76  2.775000e+01      3.964286       1.982143       1.321429       0.991071
# 77  2.775000e+01      0.000000       0.000000       0.000000       0.000000
# 78  2.775000e+01      0.000000       0.000000       0.000000       0.000000
# 79  2.775000e+01      0.000000       0.000000       0.000000       0.000000
# 80  2.775000e+01      0.000000       0.000000       0.000000       0.000000
# 81  2.775000e+01      0.000000       0.000000       0.000000       0.000000
# 82  2.775000e+01      0.000000       0.000000       0.000000       0.000000
# 83  4.463000e+01     -1.552857       1.205714       0.803810       0.602857
# 84  6.023000e+01      2.228571       1.114286       0.742857       0.557143
# 85  6.023000e+01      0.000000       0.000000       0.000000       0.000000
# 86  6.023000e+01      0.000000       0.000000       0.000000       0.000000
# 87  6.023000e+01      0.000000       0.000000       0.000000       0.000000
# 88  6.023000e+01      0.000000       0.000000       0.000000       0.000000
#
#     Month  Day  target
# 29     12   27    0.00
# 30     12   28    0.00
# 31     12   29    0.00
# 32     12   30    0.00
# 33     12   31    0.00
# 34      1    1    0.00
# 35      1    2    0.00
# 36      1    3    0.00
# 37      1    4    0.00
# 38      1    5    0.00
# 39      1    6    0.00
# 40      1    7    0.00
# 41      1    8    0.00
# 42      1    9    0.00
# 43      1   10    0.00
# 44      1   11    0.00
# 45      1   12   27.75
# 46      1   13   27.75
# 47      1   14   27.75
# 48      1   15   27.75
# 49      1   16   27.75
# 50      1   17   27.75
# 51      1   18   27.75
# 52      1   19   44.63
# 53      1   20   60.23
# 54      1   21   60.23
# 55      1   22   60.23
# 56      1   23   60.23
# 57      1   24   60.23
# 58      1   25   60.23
# 59      1   26   60.23
# 60      1   27   60.23
# 61      1   28   60.23
# 62      1   29   60.23
# 63      1   30  111.97
# 64      1   31  111.97
# 65      2    1  111.97
# 66      2    2  111.97
# 67      2    3  111.97
# 68      2    4  111.97
# 69      2    5  111.97
# 70      2    6  111.97
# 71      2    7  111.97
# 72      2    8  111.97
# 73      2    9  111.97
# 74      2   10  111.97
# 75      2   11   84.22
# 76      2   12   84.22
# 77      2   13   84.22
# 78      2   14   84.22
# 79      2   15   84.22
# 80      2   16   84.22
# 81      2   17   84.22
# 82      2   18   70.24
# 83      2   19   54.64
# 84      2   20   54.64
# 85      2   21   54.64
# 86      2   22   54.64
# 87      2   23   54.64
# 88      2   24   54.64

# %%
country = "Australia"
plot_df = df.loc[df["Country"]==country]
plt.plot(plot_df["date"], plot_df["Price"])
plt.plot(plot_df["date"], plot_df["Price_28d"])
plt.plot(plot_df["date"], plot_df["target"])

# %% [markdown]
# Lagging works as expected. We are ready to go.

# %%
df = df.dropna()
df.to_csv("../train.csv", index=False)
